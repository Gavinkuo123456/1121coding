# %%
import pandas as pd

# %%
battle = pd.read_csv("mostbattle.csv")

# %%
damage = pd.read_csv("mostdamage.csv")

# %%
battle
# Out:
#           tanks  Avg. Battles Damage Per Game       WN8 Win Rate Ace Mastery %
# 0       Type 59           686           1,108  1,574.21   51.58%           41%
# 1           T34           642           1,163  1,405.01   49.84%           47%
# 2      B-C 25 t           407           1,940  1,841.07   50.60%           36%
# 3    B-C 155 58           397           1,419  1,310.01   48.95%           42%
# 4      Obj. 261           380           1,592  1,468.68   49.74%           39%
# 5          IS-3           379           1,124  1,292.15   49.97%           42%
# 6     AMX 13 90           373             866  1,337.54   50.33%           42%
# 7          E 25           363             992  1,558.87   51.75%           37%
# 8    T95/FV4201           354           3,025  2,386.64   57.54%           32%
# 9    FV215b 183           354           1,959  1,515.63   48.74%           40%
# 10      M53/M55           350           1,406  1,436.16   50.05%           40%
# ...

# %%
damage
# Out:
#            tanks  Avg. Battles Damage Per Game       WN8 Win Rate  \
# 0   Obj. 279 (e)           217           3,056  2,180.13   59.83%
# 1     T95/FV4201           354           3,025  2,386.64   57.54%
# 2     Carro 45 t           107           2,800  2,349.66   56.40%
# 3        114 SP2            87           2,762  2,107.47   54.11%
# 4     VK 72.01 K           161           2,712  2,192.35   56.67%
# 5         116-F3            39           2,616  2,066.25   53.61%
# 6          T95E6           100           2,565  2,375.77   54.96%
# 7       Obj. 907           260           2,530  2,288.56   56.84%
# 8        Ho-Ri 3            46           2,529  1,813.36   53.29%
# 9       Obj. 260           151           2,488  2,214.56   54.21%
# 10    Concept 1B           112           2,448  2,231.28   57.94%
# 11        Vz. 55           118           2,445  1,875.49   50.98%
# 12     AMX M4 54            88           2,344  1,847.18   51.25%
# ...

# %%
battletank = set(battle['tanks'])
battletank
# Out:
# {'AMX 13 90',
#  'B-C 155 58',
#  'B-C 25 t',
#  'E 25',
#  'FV215b 183',
#  'G.W. E 100',
#  'IS-3',
#  'KV-85',
#  'Lowe',
#  'M53/M55',
#  'Obj. 261',
#  'Progetto 46',
#  'Rhm.-B. WT',
#  'SU-130PM',
#  'T26E4',
#  'T34',
#  'T49',
#  'T95/FV4201',
#  'Type 59',
#  'WZ-111'}

# %%
damagetank = set(damage['tanks'])
damagetank
# Out:
# {'114 SP2',
#  '116-F3',
#  'AMX M4 54',
#  'BZ-75',
#  'Carro 45 t',
#  'Concept 1B',
#  'Ho-Ri 3',
#  'Kpz. 07 P(E)',
#  'Lion',
#  'Obj. 260',
#  'Obj. 279 (e)',
#  'Obj. 780',
#  'Obj. 907',
#  'T95/FV4201',
#  'T95E6',
#  'VK 72.01 K',
#  'Vz. 55',
#  'WT E 100',
#  'WZ-111 5A',
#  'WZ-111 QL'}

# %%
(battletank|damagetank)
# Out:
# {'114 SP2',
#  '116-F3',
#  'AMX 13 90',
#  'AMX M4 54',
#  'B-C 155 58',
#  'B-C 25 t',
#  'BZ-75',
#  'Carro 45 t',
#  'Concept 1B',
#  'E 25',
#  'FV215b 183',
#  'G.W. E 100',
#  'Ho-Ri 3',
#  'IS-3',
#  'KV-85',
#  'Kpz. 07 P(E)',
#  'Lion',
#  'Lowe',
#  'M53/M55',
#  'Obj. 260',
#  'Obj. 261',
#  'Obj. 279 (e)',
#  'Obj. 780',
#  'Obj. 907',
#  'Progetto 46',
#  'Rhm.-B. WT',
#  'SU-130PM',
#  'T26E4',
#  'T34',
#  'T49',
#  'T95/FV4201',
#  'T95E6',
#  'Type 59',
#  'VK 72.01 K',
#  'Vz. 55',
#  'WT E 100',
#  'WZ-111',
#  'WZ-111 5A',
#  'WZ-111 QL'}

# %%
(battletank&damagetank)
# Out:
# {'T95/FV4201'}
