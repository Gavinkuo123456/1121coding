# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('railfull.csv')
data.head()
# Out:
#   year_date  passengers  passengerkms  km per passengers  passenger twr  \
# 0      2013      972332      25322755                 26         227287
# 1    13-Jan       79702       1976517                 25          18388
# 2    13-Feb       73499       2078978                 28          18173
# 3    13-Mar       83382       2157655                 26          19699
# 4    13-Apr       77726       2071225                 27          18658
#
#    passengerkms twr  km per passengers twr    income  passengers hsr  \
# 0          10513137                     46  16875785           47487
# 1            810643                     44   1282577            3647
# 2            882552                     49   1482575            3957
# 3            878608                     45   1382548            4245
# 4            863577                     46   1418727            3913
#
#    passengerkms hsr  passengers mrt  passengerkms mrt
# 0           9118060          695667           5684434
# ...

# %%
month = pd.read_csv('month.csv')
month.head()
# Out:
#   month
# 0   Jan
# 1   Feb
# 2   Mar
# 3   Apr
# 4   May

# %%
year_income = df[(df["year_date"]=="2013")|(df["year_date"]=="2014")|(df["year_date"]=="2015")|(df["year_date"]=="2016")
               |(df["year_date"]=="2017")|(df["year_date"]=="2018")|(df["year_date"]=="2019")|(df["year_date"]=="2020")
               |(df["year_date"]=="2021")|(df["year_date"]=="2022")]
year_income.head()
# Out:
#    year_date  passengers  passengerkms  km per passengers  passenger twr  \
# 0       2013      972332      25322755                 26         227287
# 13      2014     1024083      26339952                 26         232826
# 26      2015     1062853      27110886                 26         232217
# 39      2016     1092127      27949684                 26         230365
# 52      2017     1122946      29003962                 26         232806
#
#     passengerkms twr  km per passengers twr    income  passengers hsr  \
# 0           10513137                     46  16875785           47487
# 13          11037421                     47  17892441           48025
# 26          11114977                     48  18256200           50562
# 39          10967847                     48  18126469           56586
# 52          11016324                     47  18132149           60571
#
#     passengerkms hsr  passengers mrt  passengerkms mrt
# ...

# %%
month_pass_2013 = df[(df["year_date"]=="13-Jan")|(df["year_date"]=="13-Feb")|(df["year_date"]=="13-Mar")|(df["year_date"]=="13-Apr")
               |(df["year_date"]=="13-May")|(df["year_date"]=="13-Jun")|(df["year_date"]=="13-Jul")|(df["year_date"]=="13-Aug")
               |(df["year_date"]=="13-Sep")|(df["year_date"]=="13-Oct")|(df["year_date"]=="13-Nov")|(df["year_date"]=="13-Dec")]
month_pass_2013.head()
# Out:
#   year_date  passengers  passengerkms  km per passengers  passenger twr  \
# 1    13-Jan       79702       1976517                 25          18388
# 2    13-Feb       73499       2078978                 28          18173
# 3    13-Mar       83382       2157655                 26          19699
# 4    13-Apr       77726       2071225                 27          18658
# 5    13-May       80799       2074338                 26          19021
#
#    passengerkms twr  km per passengers twr   income  passengers hsr  \
# 1            810643                     44  1282577            3647
# 2            882552                     49  1482575            3957
# 3            878608                     45  1382548            4245
# 4            863577                     46  1418727            3913
# 5            853348                     45  1329721            3905
#
#    passengerkms hsr  passengers mrt  passengerkms mrt
# 1            699108           57542            466303
# ...

# %%
month_pass_2015 = df[(df["year_date"]=="15-Jan")|(df["year_date"]=="15-Feb")|(df["year_date"]=="15-Mar")|(df["year_date"]=="15-Apr")
               |(df["year_date"]=="15-May")|(df["year_date"]=="15-Jun")|(df["year_date"]=="15-Jul")|(df["year_date"]=="15-Aug")
               |(df["year_date"]=="15-Sep")|(df["year_date"]=="15-Oct")|(df["year_date"]=="15-Nov")|(df["year_date"]=="15-Dec")]
month_pass_2015.head()
# Out:
#    year_date  passengers  passengerkms  km per passengers  passenger twr  \
# 27    15-Jan       88526       2187437                 25          19316
# 28    15-Feb       80762       2250809                 28          18568
# 29    15-Mar       92322       2263130                 25          20091
# 30    15-Apr       86979       2259310                 26          19477
# 31    15-May       89911       2286778                 25          19798
#
#     passengerkms twr  km per passengers twr   income  passengers hsr  \
# 27            894953                     46  1457345            3956
# 28            951991                     51  1609548            4140
# 29            911304                     45  1488528            4194
# 30            934681                     48  1545603            4175
# 31            943775                     48  1550332            4214
#
#     passengerkms hsr  passengers mrt  passengerkms mrt
# 27            759693           65056            531676
# ...

# %%
month_pass_2017 = df[(df["year_date"]=="17-Jan")|(df["year_date"]=="17-Feb")|(df["year_date"]=="17-Mar")|(df["year_date"]=="17-Apr")
               |(df["year_date"]=="17-May")|(df["year_date"]=="17-Jun")|(df["year_date"]=="17-Jul")|(df["year_date"]=="17-Aug")
               |(df["year_date"]=="17-Sep")|(df["year_date"]=="17-Oct")|(df["year_date"]=="17-Nov")|(df["year_date"]=="17-Dec")]
month_pass_2017.head()
# Out:
#    year_date  passengers  passengerkms  km per passengers  passenger twr  \
# 53    17-Jan       90926       2452228                 27          19774
# 54    17-Feb       86334       2259927                 26          18601
# 55    17-Mar       98169       2428844                 25          19836
# 56    17-Apr       93094       2452148                 26          19899
# 57    17-May       94331       2478055                 26          19923
#
#     passengerkms twr  km per passengers twr   income  passengers hsr  \
# 53            945059                     48  1563799            5175
# 54            888405                     48  1487823            4792
# 55            896038                     45  1452604            4950
# 56            947110                     48  1563978            5095
# 57            945948                     48  1552638            5143
#
#     passengerkms hsr  passengers mrt  passengerkms mrt
# 53            973917           65791            531962
# ...

# %%
month_pass_2020 = df[(df["year_date"]=="20-Jan")|(df["year_date"]=="20-Feb")|(df["year_date"]=="20-Mar")|(df["year_date"]=="20-Apr")
               |(df["year_date"]=="20-May")|(df["year_date"]=="20-Jun")|(df["year_date"]=="20-Jul")|(df["year_date"]=="20-Aug")
               |(df["year_date"]=="20-Sep")|(df["year_date"]=="20-Oct")|(df["year_date"]=="20-Nov")|(df["year_date"]=="20-Dec")]
month_pass_2020.head()
# Out:
#    year_date  passengers  passengerkms  km per passengers  passenger twr  \
# 92    20-Jan       96868       2675560                 28          19456
# 93    20-Feb       78211       1848098                 24          15247
# 94    20-Mar       76866       1692830                 22          14987
# 95    20-Apr       65130       1443524                 22          12841
# 96    20-May       76687       1742603                 23          15081
#
#     passengerkms twr  km per passengers twr   income  passengers hsr  \
# 92            943152                     49  1538684            6231
# 93            677638                     44  1114821            3968
# 94            614782                     41   964800            3530
# 95            530003                     41   844513            2948
# 96            643311                     43  1032930            3671
#
#     passengerkms hsr  passengers mrt  passengerkms mrt
# 92           1143652           71044            587733
# ...

# %%
month_pass_2022 = df[(df["year_date"]=="22-Jan")|(df["year_date"]=="22-Feb")|(df["year_date"]=="22-Mar")|(df["year_date"]=="22-Apr")
               |(df["year_date"]=="22-May")|(df["year_date"]=="22-Jun")|(df["year_date"]=="22-Jul")|(df["year_date"]=="22-Aug")
               |(df["year_date"]=="22-Sep")|(df["year_date"]=="22-Oct")|(df["year_date"]=="22-Nov")|(df["year_date"]=="22-Dec")]
month_pass_2022.head()
# Out:
#     year_date  passengers  passengerkms  km per passengers  passenger twr  \
# 118    22-Jan       73908       1832200                 25          13848
# 119    22-Feb       64893       1727000                 27          12613
# 120    22-Mar       85268       2079661                 24          16141
# 121    22-Apr       65814       1721652                 26          13162
# 122    22-May       49538       1158149                 23           9331
#
#      passengerkms twr  km per passengers twr   income  passengers hsr  \
# 118            639960                     46  1032368            4149
# 119            621035                     49  1022482            3973
# 120            723046                     45  1138836            4837
# 121            624279                     47  1003798            3976
# 122            408786                     44   646873            2643
#
#      passengerkms hsr  passengers mrt  passengerkms mrt
# ...

# %%
print("旅客人數年度變化?")
fig, ax = plt.subplots()
ax.set_title("Tawian railroad passengers count")
ax.set_xlabel("month")
ax.set_ylabel("passengers count")

x = month["month"]
y = month_pass_2013["passengers"]
z = month_pass_2015["passengers"]
a = month_pass_2017["passengers"]

ax.plot(x,y,'ro-',label = "2013")
ax.plot(x,z,'bo-',label = "2015")
ax.plot(x,a,'yo-',label = "2017")
leg = plt.legend(loc='lower right')
plt.grid()
print("每月走勢大致相同，旺季與淡季時間點接近，旅客人數逐年成長")
# Out:
# 旅客人數年度變化?
# 每月走勢大致相同，旺季與淡季時間點接近，旅客人數逐年成長

# %%
print("捷運旅客人數受疫情影響多少?")
fig, ax = plt.subplots()
ax.set_title("Tawian MRT passengers count")
ax.set_xlabel("month")
ax.set_ylabel("passengers count")

x = month["month"]
y = month_pass_2017["passengers mrt"]
z = month_pass_2020["passengers mrt"]
a = month_pass_2022["passengers mrt"]

ax.plot(x,y,'ro-',label = "2017")
ax.plot(x,z,'bo-',label = "2020")
ax.plot(x,a,'yo-',label = "2022")
leg = plt.legend(loc='lower right')
plt.grid()
print("疫情的那兩年的疫情尖峰期旅客數最少")
# Out:
# 捷運旅客人數受疫情影響多少?
# 疫情的那兩年的疫情尖峰期旅客數最少

# %%
print("台鐵收入走勢?")
print("台鐵收入在2013~2015逐年上漲，2015~2019變化不大，，2020~2022疫情年大幅降低")
fig, ax = plt.subplots()
ax.set_title("Tawian railroad income")
ax.set_xlabel("year")
ax.set_ylabel("NTD")

x = year_income["year_date"]
y = year_income["income"]

ax.plot(x,y,'bo-')
plt.grid()
# Out:
# 台鐵收入走勢?
# 台鐵收入在2013~2015逐年上漲，2015~2019變化不大，，2020~2022疫情年大幅降低
