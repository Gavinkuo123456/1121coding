# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
railroad = pd.read_csv("railroad.csv")
df = railroad

# %%
railroad
# Out:
#    year  passengers  passengerkms  avg km per pass
# 0  2013       972.0    25322755.0             26.0
# 1  2014      1024.0    26339952.0             25.7
# 2  2015      1063.0    27110886.0             25.5
# 3  2016      1092.0    27949684.0             25.6
# 4  2017      1123.0    29003962.0             25.8
# 5  2018      1154.0    29624218.0             25.7
# 6  2019      1195.0    30456031.0             25.5
# 7  2020      1031.0    25566403.0             24.8
# 8  2021       792.0    19539931.0             24.7
# 9  2022       889.0    22791767.0             25.6

# %%
trace = sns.scatterplot(railroad,x = 'year',y = 'avg km per pass')

# %%
fig, ax = plt.subplots()
ax.set_title("Tawian railroad passengers count")
ax.set_xlabel("year")
ax.set_ylabel("passengers count(1000)")

x = df["year"]
y = df["passengers"]

ax.plot(x,y,'bo-')
plt.grid()
