# %%
import pandas as pd

# %%
weather2022 = pd.read_csv("466910-2022-09-13.csv")
weather2023 = pd.read_csv("466910-2023-09-13.csv")

# %%
weather2022
# Out:
#     ObsTime  StnPres  SeaPres  Temperature  Td dew point   RH    WS   WD  \
# 0         1    912.1   1438.3         21.0          21.0  100  10.4  360
# 1         2    912.1   1439.4         21.1          21.1  100   7.9  360
# 2         3    911.3   1432.1         21.0          21.0  100  10.7  360
# 3         4    911.4   1432.4         20.7          20.7  100   8.3  360
# 4         5    911.7   1434.9         20.5          20.5  100   8.4  360
# 5         6    911.9   1436.8         20.8          20.8  100   8.7  360
# 6         7    912.3   1439.7         20.2          20.2  100   9.6  360
# 7         8    912.4   1440.8         20.3          20.3  100  10.6  360
# 8         9    912.5   1441.6         20.4          20.4  100  10.0  350
# 9        10    912.6   1442.5         20.5          20.5  100  10.5  360
# 10       11    912.9   1445.5         20.4          20.4  100   9.7  350
# 11       12    913.2   1448.5         20.3          20.3  100   6.7  340
# ...

# %%
weather2023
# Out:
#     ObsTime  StnPres  SeaPres  Temperature  Td dew point  RH   WS   WD  \
# 0         1    918.1   1499.6         19.2          18.4  95  0.6  200
# 1         2    917.7   1495.8         19.3          18.3  94  0.7   50
# 2         3    917.3   1490.7         19.0          18.2  95  1.8  360
# 3         4    917.2   1488.5         20.0          18.0  88  1.0  360
# 4         5    917.4   1488.7         19.0          18.2  95  1.6  350
# 5         6    917.6   1488.7         18.9          18.6  98  1.5  350
# 6         7    917.8   1491.7         20.4          19.6  95  1.2   20
# 7         8    917.8   1494.0         22.7          20.4  87  0.7  200
# 8         9    918.0   1496.9         24.3          21.6  85  1.0  190
# 9        10    918.2   1500.0         26.0          23.1  84  0.9  140
# 10       11    918.0   1496.0         23.8          22.8  94  1.3  350
# 11       12    917.7   1492.8         24.5          23.1  92  1.5  340
# ...

# %%
temp2022 = list(weather2022['Temperature'])
temp2022
# Out:
# [21.0,
#  21.1,
#  21.0,
#  20.7,
#  20.5,
#  20.8,
#  20.2,
#  20.3,
#  20.4,
#  20.5,
#  20.4,
#  20.3,
#  20.1,
#  20.2,
#  20.1,
#  20.1,
#  20.3,
#  20.3,
#  20.3,
#  20.3,
#  20.3,
#  19.9,
#  19.9,
#  19.5]

# %%
temp2023 = list(weather2023['Temperature'])
temp2023
# Out:
# [19.2,
#  19.3,
#  19.0,
#  20.0,
#  19.0,
#  18.9,
#  20.4,
#  22.7,
#  24.3,
#  26.0,
#  23.8,
#  24.5,
#  22.6,
#  23.1,
#  22.7,
#  22.1,
#  21.8,
#  20.1,
#  20.1,
#  19.6,
#  20.0,
#  20.3,
#  20.2,
#  20.3]
