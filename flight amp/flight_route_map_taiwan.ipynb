# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
import airportsdata
import pandas as pd
airports = airportsdata.load('IATA')

# %%
flight_data = pd.read_csv("flight route csv.csv")
flight_data.head()
# Out:
#   start  end  flights per week distance
# 0   KHH  PVG                 6      962
# 1   KHH  KIX                12    2,057
# 2   KHH  KUL                 6    2,977
# 3   KHH  NGO                 4    2,283
# 4   KHH  NRT                28    2,519

# %%
m = Basemap(projection='cyl',llcrnrlat=-90,urcrnrlat=90,\
            llcrnrlon=-180,urcrnrlon=180,resolution='c')
m.shadedrelief()
for i,j in zip(flight_start,flight_end):
    m.drawgreatcircle(airports[i]['lon'],airports[i]['lat'],airports[j]['lon'],airports[j]['lat'],linewidth=0.25,color='black')
plt.show()
